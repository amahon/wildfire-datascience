# %%
import rasterio
import rasterio.mask
from rasterio import plot
import matplotlib.pyplot as plt

import fiona
import shapely
#from rasterio.windows import Window, WindowMethodsMixin

# %%
print(rasterio.__version__)
print(shapely.__version__)
print(fiona.__version__)
# Out:
# 1.0a12
# 1.6.4.post1
# 1.7.11

# %%
data_path = "/data/188-million-us-wildfires/src/nlcd_2011_landcover_2011_edition_2014_10_10/nlcd_2011_landcover_2011_edition_2014_10_10.img"
dataset = rasterio.open(data_path, crs='SR-ORG:6670')
print(dataset.name)
print(dataset.mode)
print(dataset.closed)
print(dataset.count)
print(dataset.width)
print(dataset.height)
print(dataset.bounds)
print(" ")
print(dataset.transform)
print(dataset.transform * (0,0))
print(dataset.transform * (dataset.width, dataset.height))
print(" ")
print()
print(" ")
print(dataset.crs)
print(" ")
print(dataset.crs.wkt)
# Out:
# /data/188-million-us-wildfires/src/nlcd_2011_landcover_2011_edition_2014_10_10/nlcd_2011_landcover_2011_edition_2014_10_10.img
# r
# False
# 1
# 161190
# 104424
# BoundingBox(left=-2493045.0, bottom=177285.0, right=2342655.0, top=3310005.0)
#
# | 30.00, 0.00,-2493045.00|
# | 0.00,-30.00, 3310005.00|
# | 0.00, 0.00, 1.00|
# (-2493045.0, 3310005.0)
# (2342655.0, 177285.0)
#
#
#
# CRS({'proj': 'aea', 'lat_1': 29.5, 'lat_2': 45.5, 'lat_0': 23, 'lon_0': -96, 'x_0': 0, 'y_0': 0, 'ellps': 'GRS80', 'towgs84': '0,0,0,-0,-0,-0,0', 'units': 'm', 'no_defs': True})
#
# PROJCS["unnamed",GEOGCS["GRS 1980(IUGG, 1980)",DATUM["unknown",SPHEROID["GRS80",6378137,298.257222101],TOWGS84[0,0,0,-0,-0,-0,0]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433]],PROJECTION["Albers_Conic_Equal_Area"],PARAMETER["standard_parallel_1",29.5],PARAMETER["standard_parallel_2",45.5],PARAMETER["latitude_of_center",23],PARAMETER["longitude_of_center",-96],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["Meter",1]]

# %%
from functools import partial
import pyproj
import geopandas as gpd
from shapely.ops import transform

zone_path = "/data/188-million-us-wildfires/map.geojson"
gdf = gpd.read_file(zone_path)

project = partial(
    pyproj.transform,
    pyproj.Proj(init='EPSG:4326'),
    pyproj.Proj('+proj=aea +lat_1=29.5 +lat_2=45.5 +lat_0=23 +lon_0=-96 +x_0=0 +y_0=0 +ellps=GRS80 +datum=NAD83 +units=m +no_defs'))

def reproject(row):
    return transform(project, row["geometry"])

gdf["geometry"] = gdf.apply(reproject, axis=1)

display(gdf)
# Out:
#                                             geometry
# 0  POLYGON ((-641325.6639480502 2272431.511255356...

# %%
from rasterstats import zonal_stats
stats = zonal_stats(
    [shapely.geometry.mapping(gdf.loc[0]['geometry'])],
    data_path,
    categorical=True,
    stats=['count',  'unique'],
    geojson_out=True
)
stats
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-b4f86cd94de5> in <module>()
#       5     categorical=True,
#       6     stats=['count',  'unique', 'categorical'],
# ----> 7     geojson_out=True
#       8 )
#       9 stats
#
# /opt/conda/lib/python3.6/site-packages/rasterstats/main.py in zonal_stats(*args, **kwargs)
#      26     The only difference is that ``zonal_stats`` will
#      27     return a list rather than a generator."""
# ---> 28     return list(gen_zonal_stats(*args, **kwargs))
#      29
#      30
#
# /opt/conda/lib/python3.6/site-packages/rasterstats/main.py in gen_zonal_stats(vectors, raster, layer, band, nodata, affine, stats, all_touched, categorical, category_map, add_stats, zone_func, raster_out, prefix, geojson_out, **kwargs)
#     119         GeoJSON-like Feature as python dict
#     120     """
# --> 121     stats, run_count = check_stats(stats, categorical)
#     122
#     123     # Handle 1.0 deprecations
#
# /opt/conda/lib/python3.6/site-packages/rasterstats/utils.py in check_stats(stats, categorical)
#      94             raise ValueError(
#      95                 "Stat `%s` not valid; "
# ---> 96                 "must be one of \n %r" % (x, VALID_STATS))
#      97
#      98     run_count = False
#
# ValueError: Stat `categorical` not valid; must be one of
#  ['count', 'min', 'max', 'mean', 'sum', 'std', 'median', 'majority', 'minority', 'unique', 'range', 'nodata']

# %%
display(dataset)
# Out:
# <open DatasetReader name='/data/188-million-us-wildfires/src/nlcd_2011_landcover_2011_edition_2014_10_10/nlcd_2011_landcover_2011_edition_2014_10_10.img' mode='r'>

# %%
out_image, out_transform = rasterio.mask.mask(
    dataset,
    [shapely.geometry.mapping(gdf.loc[0]['geometry'])],
    crop=True
)
out_meta = dataset.meta.copy()
out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

with rasterio.open("/data/188-million-us-wildfires/masked.tif", "w", **out_meta) as dest:
    dest.write(out_image)

# %% [markdown]
# ---

# %%
data_path = r"/data/188-million-us-wildfires/masked.tif"
masked_dataset = rasterio.open(data_path)
plot.show((maksed_dataset, 2))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-a1d8ec8cbd57> in <module>()
#       1 data_path = r"/data/188-million-us-wildfires/masked.tif"
#       2 masked_dataset = rasterio.open(data_path)
# ----> 3 plot.show((maksed_dataset, 2))
#
# /opt/conda/lib/python3.6/site-packages/rasterio/plot.py in show(source, with_bounds, contour, contour_label_kws, ax, title, transform, adjust, **kwargs)
#      83
#      84     if isinstance(source, tuple):
# ---> 85         arr = source[0].read(source[1])
#      86         if len(arr.shape) >= 3:
#      87             arr = reshape_as_image(arr)
#
# rasterio/_io.pyx in rasterio._io.DatasetReaderBase.read()
#
# IndexError: band index out of range

# %%
world = rasterio.open(r"/data/188-million-us-wildfires/world.rgb.tif")
plot.show((world, 2), cmap='viridis')
# Out:
# CRS({'init': 'epsg:4326'})
